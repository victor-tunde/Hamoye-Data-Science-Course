# %% [markdown]
# <a href="https://colab.research.google.com/github/victor-tunde/Hamoye-Data-Science-Course/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
url = 'https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv'
df = pd.read_csv(url, encoding='latin-1')
df.head()
df.isnull().sum()
#df.groupby( 'Item' )
df.groupby( 'Item' )[ 'Item' ].count()
#df[[ 'Item' ]] = df[[ 'Item' ]]
df.isnull().sum()
df.groupby( 'Y2014' )[ 'Y2014' ].count().sum()
# Out:
# 59354

# %%
import pandas as pd 
url = 'https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv'
df = pd.read_csv(url, encoding='latin-1')
df.head()
df.isnull().sum()

df.isnull().sum()
#df.groupby( 'Y2015' )[ 'Y2015' ].mean()
df.describe(include='all')
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit          Y2014  \
# count   60943.000000                     60943        60943   59354.000000
# ...

# %%
import pandas as pd 
url = 'https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv'
df = pd.read_csv(url, encoding='latin-1')

df.isnull().count()
# Out:
# Area Code       60943
# Area            60943
# Item Code       60943
# Item            60943
# Element Code    60943
# Element         60943
# Unit            60943
# Y2014           60943
# Y2015           60943
# Y2016           60943
# Y2017           60943
# Y2018           60943
# dtype: int64
